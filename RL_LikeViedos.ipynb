# %% [markdown]
# ## Montamos unidad de  Drive en colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importamos librerias

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.metrics import r2_score

# %% [markdown]
# ##Varible para el modelo lineal

# %%
regr=linear_model.LinearRegression()
datos=pd.read_csv('/content/drive/MyDrive/cursos virtuales I-2021/Inteligencia Artificial/programas colab/Regresión lineal/movies2.csv')
datos
# Out:
#     num  color  ... aspect_ratio  movie_facebook_likes
# 0     1  Color  ...         1.78                 33000
# 1     2  Color  ...         2.35                     0
# 2     3  Color  ...         2.35                 85000
# 3     4  Color  ...         2.35                164000
# 4     5  Color  ...          NaN                     0
# 5     6  Color  ...         2.35                 24000
# 6     7  Color  ...         2.35                     0
# 7     8  Color  ...         1.85                 29000
# 8     9  Color  ...         2.35                118000
# 9    10  Color  ...         2.35                 10000
# 10   11  Color  ...         2.35                197000
# 11   12  Color  ...         2.35                     0
# 12   13  Color  ...         2.35                     0
# 13   14  Color  ...         2.35                  5000
# 14   15  Color  ...         2.35                 48000
#
# [15 rows x 29 columns]

# %% [markdown]
# ##Creamos el dataFrame

# %%
df=pd.DataFrame(datos)
#asignamos los valores a x y y
x=df['movie_facebook_likes']
y=df['imdb_score']
x
y

# %% [markdown]
# ##Entrenamiento

# %%
X=x[:,np.newaxis]
print(X)
print(regr.fit(X,y))
print(regr.coef_)
m=regr.coef_[0]
b=regr.intercept_
y_p=m*X+b
print('y={0}*x+{1}'.format(m,b))
# Out:
# [[ 33000]
#  [     0]
#  [ 85000]
#  [164000]
#  [     0]
#  [ 24000]
#  [     0]
#  [ 29000]
#  [118000]
#  [ 10000]
#  [197000]
#  [     0]
#  [     0]
#  [  5000]
#  [ 48000]]
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# [3.84816446e-06]
# y=3.8481644646998285e-06*x+6.917083915777934
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## reslizar la predicción

# %%
print(regr.predict(X)[0:5])
# Out:
# [7.04407334 6.91708392 7.2441779  7.54818289 6.91708392]

# %% [markdown]
# ## predicción

# %%
print("el valor de r^2",r2_score(y,y_p))
# Out:
# el valor de r^2 0.13918361083362363

# %% [markdown]
# #Grafica

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color='blue')
plt.plot(x,y_p,color='red')
plt.title('Regresión lineal',fontsize=16)
plt.xlabel('Likes Facebook',fontsize=13)
plt.ylabel('Calificación IMDB',fontsize=13)
# Out:
# Text(0, 0.5, 'Calificación IMDB')
