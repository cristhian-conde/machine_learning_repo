# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#### CARGAR LOS DATOS ####
data = pd.read_csv('/content/drive/MyDrive/Wholesale customers data.csv')

# %%
#ANALIZAR LOS DATOS
#Conocer la forma de los datos
data.shape
# Out:
# (440, 8)

# %%
#Conocer los datos nulos
data.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
#Conocer el formato de los datos
data.dtypes
# Out:
# Channel             int64
# Region              int64
# Fresh               int64
# Milk                int64
# Grocery             int64
# Frozen              int64
# Detergents_Paper    int64
# Delicassen          int64
# dtype: object

# %%
#Se selecionan unos datos al azar para posteriormente probar los resultados
indices = [26,176,392]
muestras = pd.DataFrame(data.loc[indices],
columns = data.keys()).reset_index(drop = True)
data = data.drop(indices, axis = 0)

# %%
#PROCESAMIENTO DE LOS DATOS
#Eliminamos las columnas de región y canal
data = data.drop(['Region', 'Channel'], axis = 1,)
muestras = muestras.drop(['Region', 'Channel'], axis = 1,)

# %%
#Se realiza el escalmiento de los datos
from sklearn import preprocessing
data_escalada = preprocessing.Normalizer().fit_transform(data)
muestras_escalada = preprocessing.Normalizer().fit_transform(muestras)

# %%
#ANÁLISIS DE MACHINE LEARNING
#Se determina las variables a evaluar
X = data_escalada
from sklearn.cluster import DBSCAN

# %%
#Se define el algoritmo
algoritmo = DBSCAN(eps = 0.13, min_samples = 1)
#Se entrena el algoritmo
algoritmo.fit(X)
pred1 = algoritmo.fit_predict(X)

# %%
#Utilicemos los datos de muestras y verifiquemos en que cluster se encuentran
muestra_prediccion = algoritmo.fit_predict(muestras_escalada)
for i, pred in enumerate(muestra_prediccion):
  print( "Muestra", i, "se encuentra en el clúster:", pred)
# Out:
# Muestra 0 se encuentra en el clúster: 0
# Muestra 1 se encuentra en el clúster: 1
# Muestra 2 se encuentra en el clúster: 2
